# %%
L=[1,4,7,9]
x = sum(L)
y = len(L)
print("sum is", x)
print("count is", y)
# Out:
# sum is 21
# count is 4

# %%
M=[14,42,17,19]
x= sum(M)
y=len(M)
print("sum is", x)
print("count is", y)000
# Out:
# sum is 92
# count is 4

# %%
p=[24,73,56,28,19,18,17,34,71]
x= sum(p)
y=len(p)
print("sum is", x)
print("count is", y)
# Out:
# sum is 340
# count is 9

# %%
p=[24,73,56,28,19,18,17,34,71]
x= sum(p)
y=len(p)
print("sum i6s", x)
print("count is", y)
print("mean",x/y)
# Out:
# sum is 340
# count is 9
# mean 37.77777777777778

# %%
Q=[24,19,18,17,34,71]
x= sum(Q)
y=len(Q)
print("sum i6s", x)
print("count is", y)
print("mean",x/y)
# Out:
# sum i6s 183
# count is 6
# mean 30.5

# %%
s=[3,6,4,8]
x= sum(s)
y=len(s)
print("Total",x)
print("count",y)
print("mean",x/y)
# Out:
# Total 21
# count 4
# mean 5.25

# %%
F=[13,63,42,81]
x= sum(F)
y=len(F)
print("Sum",x)
print("Count",y)
print("Mean",x/y)
# Out:
# Sum 199
# Count 4
# Mean 49.75

# %%
dataset =[1,4,7,9,11]
x= sum(dataset)
y=len(dataset)
print("Sum",x)
print("Count",y)
print("Mean",x/y)
# Out:
# Sum 32
# Count 5
# Mean 6.4

# %%
dataset.sort
N=len(dataset)
if N%2==0:
    median=(dataset[N//2]+dataset[N//2-1]) / 2
else:
    median=dataset[N//2]
print(dataset)
print(median)
# Out:
# [1, 4, 7, 9, 11]
# 7

# %%
K=[2,4,5,6,8,9,12,14,15,17,19]
print(K[0])
print(K[1])
print(K[2])
print(K[3])
print(K[4])
print(K[5])
print(K[6])
print(K[7])
print(K[8])
print(K[9])
print(K[10])
N=len(K)
print("len",L)
mid_point=N//2
print("mid_point",mid_point)
# Out:
# 2
# 4
# 5
# 6
# 8
# 9
# 12
# 14
# 15
# 17
# 19
# len 11
# mid_point 5

# %%
print(K[mid_point])
# Out:
# 9

# %%
l1=[8,9,10,11,12,15]
n=len(l1)
print(x)
y= sum(l1)
print(y)
print("mean",x/y)
if n%2==0:
    median=(l1[n//2]+l1[n//2-1])/2
else:
    median=dl1[n//2]
print(median)
# Out:
# 6
# 65
# mean 0.09230769230769231
# 10.5

# %%
P = [12, 14, 15, 16]

print(P[0])
print(P[1])
print(P[2])
print(P[3])

n = len(P)


midpos_1 = n//2 - 1      
midpos_2 = n//2         

print(midpos_1, midpos_2)

print(P[midpos_1], P[midpos_2])
# Out:
# 12
# 14
# 15
# 16
# 1 2
# 14 15

# %%
Q = [12, 14, 15, 16, 18, 19]


print(Q[0])

print(Q[0:])

# B
n = len(Q)
midpos1 = n // 2 - 1 
midpos2 = n // 2      
print(midpos1, midpos2)

print(Q[midpos1], Q[midpos2])
# Out:
# 12
# [12, 14, 15, 16, 18, 19]
# 2 3
# 15 16

# %%
# R= [12, 14, 15, 16, 18, 19, 20, 22] 
# a. print the value of R[0], R[1], R[2], R[3]
# b. print the index of mid positions of this list 
# c. print the value at index of mid position of this list

# %%
R = [12, 14, 15, 16, 18, 19, 20, 22]

print(R[0], R[1], R[2], R[3], R[4], R[5], R[6], R[7])

print(R[:])

l = len(R)

midpos1 = l//2 - 1   # first middle index
midpos2 = l//2       # second middle index

print(midpos1, midpos2)

# Print the values at mid positions
print(R[midpos1], R[midpos2])
