# %%
L=[1,4,7,9]
x = sum(L)
y = len(L)
print("sum is", x)
print("count is", y)
# Out:
# sum is 21
# count is 4

# %%
M=[14,42,17,19]
x= sum(M)
y=len(M)
print("sum is", x)
print("count is", y)000
# Out:
# sum is 92
# count is 4

# %%
p=[24,73,56,28,19,18,17,34,71]
x= sum(p)
y=len(p)
print("sum is", x)
print("count is", y)
# Out:
# sum is 340
# count is 9

# %%
p=[24,73,56,28,19,18,17,34,71]
x= sum(p)
y=len(p)
print("sum i6s", x)
print("count is", y)
print("mean",x/y)
# Out:
# sum is 340
# count is 9
# mean 37.77777777777778

# %%
Q=[24,19,18,17,34,71]
x= sum(Q)
y=len(Q)
print("sum i6s", x)
print("count is", y)
print("mean",x/y)
# Out:
# sum i6s 183
# count is 6
# mean 30.5

# %%
s=[3,6,4,8]
x= sum(s)
y=len(s)
print("Total",x)
print("count",y)
print("mean",x/y)
# Out:
# Total 21
# count 4
# mean 5.25

# %%
F=[13,63,42,81]
x= sum(F)
y=len(F)
print("Sum",x)
print("Count",y)
print("Mean",x/y)
# Out:
# Sum 199
# Count 4
# Mean 49.75
